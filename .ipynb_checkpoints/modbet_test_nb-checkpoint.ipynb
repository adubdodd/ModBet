# %% [markdown]
# # Moptibet
# Moptibet gathers betting odd’s data from multiple sources, consolidate said data, and highlight betting opportunities, through both arbitrage due to inconsistent odds in the market and using predictive analytics to guess winners.
#
# ### Imports

# %%
import pandas as pd
import numpy as np
import sqlalchemy as db
import sys

# %%
from datetime import datetime
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from bs4 import BeautifulSoup

# %% [markdown]
# ### Web Scraping
#
# #### Site Specific HTML Parsers

# %%
def draftkings_parse(input_dict, driver, key):
    outcomes = [x.text for x in driver.find_elements_by_class_name(input_dict['outcomes_class'])]
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    odds = [x.text for x in soup.findAll('span',{'class', input_dict['odds_class']})]
    # odds = [x.text for x in driver.find_elements_by_class_name(input_dict['odds_class'])]
    return list(zip(outcomes[::3], outcomes[2::3], odds[::3], odds[1::3], odds[2::3], [key] * len(outcomes[::3]), [datetime.now()] * len(outcomes[::3])))

def fanduel_parse(input_dict, driver, key):
    outcomes = [x.text for x in driver.find_elements_by_class_name(input_dict['outcomes_class'])]
    odds = [x.text for x in driver.find_elements_by_class_name(input_dict['odds_class'])]
    return list(zip(outcomes[::2], outcomes[1::2], odds[::3], odds[1::3], odds[2::3], [key] * len(outcomes[::3]), [datetime.now()] * len(outcomes[::3])))

def bovada_parse(input_dict, driver, key):
    outcomes = [x.text for x in driver.find_elements_by_class_name(input_dict['outcomes_class'])]
    odds = [x.text for x in driver.find_elements_by_class_name(input_dict['odds_class'])]
    return list(zip(outcomes[::2], outcomes[1::2], odds[2::7], odds[4::7], odds[3::7], [key] * len(outcomes[::3]), [datetime.now()] * len(outcomes[::3])))

# %% [markdown]
# #### Site Specific Scraper Mapping

# %%
prem_dir = {'draftkings':{'url':'https://sportsbook.draftkings.com/leagues/soccer/53591936',
                          'parser': draftkings_parse,
                          'args':{'outcomes_class':'sportsbook-outcome-cell__label',
                                  'odds_class':'sportsbook-odds american default-color'}},
            'fanduel':{'url':'https://sportsbook.fanduel.com/sports/navigation/730.1/7567.1',
                       'parser': fanduel_parse,
                       'args':{'outcomes_class':'name',
                               'odds_class':'selectionprice'}},
            'bovada':{'url':'https://www.bovada.lv/sports/soccer/england-premier-league',
                      'parser': bovada_parse,
                      'args':{'outcomes_class':'name',
                              'odds_class':'bet-price'}}
           }

output_cols = ['home_team','away_team', 'home_odds','tie_odds', 'away_odds', 'source', 'datetime']

# %% [markdown]
# #### Setting Scraper settings and appropriate driver

# %%
sys.platform
# Out:
# 'darwin'

# %%
options = Options()
options.headless = True
options.add_argument("--window-size=1920,1200")

if sys.platform == 'darwin':
    DRIVER_PATH = 'driver/mac/chromedriver'
elif sys.platform == 'linux' or sys.platform == 'linux2':
    DRIVER_PATH = 'driver/linux/chromedriver'
elif sys.platform == 'win32':
    DRIVER_PATH = 'driver/windows/chromedriver'

# %% [markdown]
# #### Iterate over sites, persisting outcomes, odds

# %%
class Web_Scraper:
    def __init__(self, map_dir, output_cols, scr_options=None):
        self.map_dir = map_dir
        self.output_cols = output_cols
        self.scr_options = scr_options
        
    def set_options(self):
        if self.scr_options is not None:
            options = Options()
            options.headless = self.scr_options['headless']
            options.add_argument(''.join('--window-size=',self.scr_options['width'],',',self.scr_options['height']))
        else:
            options = Options()
            options.headless = True
            options.add_argument('--window-size=1920,1200')
    
    def os_driver_path(self):
        if sys.platform == 'darwin':
            DRIVER_PATH = 'driver/mac/chromedriver'
        elif sys.platform == 'linux' or sys.platform == 'linux2':
            DRIVER_PATH = 'driver/linux/chromedriver'
        elif sys.platform == 'win32':
            DRIVER_PATH = 'driver/windows/chromedriver'
        return DRIVER_PATH
    
    def go(self):
        dn = []
        for key in self.map_dir:
            driver = webdriver.Chrome(options=self.set_options(), executable_path=self.os_driver_path())
            driver.get(self.map_dir[key]['url'])
            driver.implicitly_wait(3)
            
            data = pd.DataFrame(prem_dir[key]['parser'](prem_dir[key]['args'],driver, key),columns=self.output_cols)
            dn.append(data)
            driver.quit()
        return pd.concat(dn, axis=0)
   
    ##########
    #
    # N E X T
    #
    ##########

    def update_db(self):
        pass

# %%
Prem_Web_Scraper = Web_Scraper(prem_dir, output_cols)

# %%
test = Prem_Web_Scraper.go()

# %%
test.to_sql()
# Out:
#          home_team                away_team home_odds tie_odds away_odds  \
# 0   Leicester City        Manchester United      +205     +250      +130
# 1  Manchester City             Norwich City     -1250    +1100     +2800
# 2         West Ham              Aston Villa      +220     +245      +123
# 3          Burnley                 Brighton      +135     +235      +205
# 4        Newcastle                Liverpool      +750     +400      -275
# 5          Everton              Bournemouth      +128     +275      +190
# 6          Chelsea                   Wolves      -118     +280      +310
# 7      Southampton         Sheffield United      +123     +240      +225
# 8   Crystal Palace                Tottenham      +480     +310      -175
# 9          Arsenal                  Watford      -106     +285      +265
# 0         West Ham              Aston Villa      +220     +250      +120
# 1          Everton              Bournemouth      +125     +270      +195
# 2          Burnley                 Brighton      +135     +240      +200
# 3        Newcastle                Liverpool      +700     +420      -290
# 4        Leicester                  Man Utd      +200     +250      +125
# 5         Man City                  Norwich     -1200    +1100     +2900
# 6      Southampton                Sheff Utd      +120     +240      +230
# 0          Arsenal                  Watford      -110     +280      +270
# 1          Burnley                 Brighton      +135     +240      +205
# 2          Chelsea  Wolverhampton Wanderers      -120     +280      +315
# 3   Crystal Palace        Tottenham Hotspur      +500     +310      -185
# 4          Everton              Bournemouth      +125     +285      +195
# 5   Leicester City        Manchester United      +210     +250      +130
# 6  Manchester City             Norwich City     -1200    +1100     +3000
#
#        source                   datetime
# 0  draftkings 2020-07-23 01:14:50.661729
# 1  draftkings 2020-07-23 01:14:50.661729
# 2  draftkings 2020-07-23 01:14:50.661729
# 3  draftkings 2020-07-23 01:14:50.661729
# 4  draftkings 2020-07-23 01:14:50.661729
# 5  draftkings 2020-07-23 01:14:50.661729
# 6  draftkings 2020-07-23 01:14:50.661729
# 7  draftkings 2020-07-23 01:14:50.661729
# 8  draftkings 2020-07-23 01:14:50.661729
# 9  draftkings 2020-07-23 01:14:50.661729
# 0     fanduel 2020-07-23 01:14:57.558341
# 1     fanduel 2020-07-23 01:14:57.558341
# 2     fanduel 2020-07-23 01:14:57.558341
# 3     fanduel 2020-07-23 01:14:57.558341
# 4     fanduel 2020-07-23 01:14:57.558341
# 5     fanduel 2020-07-23 01:14:57.558341
# 6     fanduel 2020-07-23 01:14:57.558341
# 0      bovada 2020-07-23 01:15:04.549800
# 1      bovada 2020-07-23 01:15:04.549800
# 2      bovada 2020-07-23 01:15:04.549800
# 3      bovada 2020-07-23 01:15:04.549800
# 4      bovada 2020-07-23 01:15:04.549800
# 5      bovada 2020-07-23 01:15:04.549800
# 6      bovada 2020-07-23 01:15:04.549800

# %% [markdown]
# #### Grab Probabilities and Fixtures from 538

# %%
matches_538 = pd.read_csv('https://projects.fivethirtyeight.com/soccer-api/club/spi_matches_latest.csv')
prem_matches = matches_538[matches_538['league'] == 'Barclays Premier League']

columns = ['date', 'league', 'team1', 'team2', 'spi1',
       'spi2', 'prob1', 'prob2', 'probtie', 'proj_score1', 'proj_score2',
       'importance1', 'importance2', 'score1', 'score2', 'xg1', 'xg2', 'nsxg1',
       'nsxg2', 'adj_score1', 'adj_score2']

prem_matches[prem_matches['date']=='2020-07-16']
# Out:
#       season        date  league_id                   league           team1  \
# 8756    2019  2020-07-16       2411  Barclays Premier League         Everton
# 8760    2019  2020-07-16       2411  Barclays Premier League  Leicester City
# 8775    2019  2020-07-16       2411  Barclays Premier League     Southampton
# 8776    2019  2020-07-16       2411  Barclays Premier League  Crystal Palace
#
#                          team2   spi1   spi2   prob1   prob2     ...      \
# 8756               Aston Villa  74.56  63.46  0.4572  0.2793     ...
# 8760          Sheffield United  80.58  73.52  0.5859  0.1605     ...
# 8775  Brighton and Hove Albion  73.64  69.29  0.4521  0.2844     ...
# 8776         Manchester United  68.30  88.10  0.1098  0.6879     ...
#
#       importance1  importance2  score1  score2   xg1   xg2  nsxg1  nsxg2  \
# 8756          0.0         59.5     1.0     1.0  1.08  1.26   1.54   1.02
# 8760        100.0          2.0     2.0     0.0  3.05  0.84   1.48   0.29
# 8775          0.0          1.8     1.0     1.0  2.39  0.89   1.28   1.02
# 8776          0.0        100.0     0.0     2.0  0.60  1.94   0.96   2.14
#
#       adj_score1  adj_score2
# 8756        1.05        1.05
# 8760        1.86        0.00
# 8775        1.05        1.05
# 8776        0.00        1.91
#
# [4 rows x 23 columns]

# %% [markdown]
# #### Connect to Remote PostgreSQL server

# %%
# need to hide password

DB_URI = 'postgres+psycopg2://austin:stretford20x@ubuntu_t_serv/modbet'

conn = db.create_engine(DB_URI).connect()

# %%
results = pd.read_sql('SELECT * FROM test.test;', conn)
results.head()
# Out:
#        coltest
# 0  Hello World

# %%
conn.close()
